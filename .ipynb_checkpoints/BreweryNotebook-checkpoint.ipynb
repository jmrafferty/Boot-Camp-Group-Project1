# %%
import json
import pandas as pd
from pprint import pprint
import datetime

file = "Brewery_DistilleryData.csv"

# %%
brewerydf = pd.read_csv(file)
brewerydf.fillna(0, inplace = True)
brewerydf.head()

#reformat date column to eliminate timestamps
brewerydf['Issue Date'] = pd.to_datetime(brewerydf['Issue Date'])

brewerydf.head(100)
# Out:
#        #     File Number                           Trade Name  \
# 0    1.0               -                  Ivory Tower Brewery
# 1    2.0               -                       Trophy Brewing
# 2    3.0               -              Hosanna Brewing Company
# 3    4.0               -           Tryon Back Door Distillery
# 4    5.0               -            Blackjack Brewing Company
# ..   ...             ...                                  ...
# 95   0.0  00090855CM-998            Asheville Brewing Company
# 96  73.0  00090855CM-997  Asheville Pizza and Brewing Company
# 97   0.0  00090855CM-997  Asheville Pizza and Brewing Company
# 98  74.0  00095513DI-999                  Piedmont Distillers
# 99  75.0  00096488CM-999            Liberty Brewery and Grill
#
#                                            Corp Name Business Status  \
# 0                       Appalachian State University       Withdrawn
# 1                                  Grain Raleigh LLC       Withdrawn
# 2                            Hosanna Brewing Company       Withdrawn
# 3                     Tryon Back Door Distillery LLC       Withdrawn
# 4                      Blackjack Brewing Company LLC       Withdrawn
# ..                                               ...             ...
# 95           Asheville Pizza and Brewing Company Inc          Active
# 96           Asheville Pizza and Brewing Company Inc          Active
# 97           Asheville Pizza and Brewing Company Inc          Active
# 98                           Piedmont Distillers Inc       Cancelled
# 99  Liberty Steakhouse and Brewery of High Point Inc          Active
#
#                               Address           City  State    Zip  \
# 0               775 Bodenheimer Drive          Boone    0.0  28608
# 1              827 West Morgan Street        Raleigh    0.0  27603
# 2     2912 North Main Street Unit 100  Fuquay Varina    0.0  27526
# 3                     77 Maple Street          Tryon    0.0  28782
# 4   1053 East Whitaker Mill Suite 101        Raleigh    0.0  27604
# ..                                ...            ...    ...    ...
# 95                     77 Coxe Avenue      Asheville    0.0  28801
# 96                 66 Asheland Avenue      Asheville    0.0  28801
# 97                 66 Asheland Avenue      Asheville    0.0  28801
# 98             203 East Murphy Street        Madison    0.0  27025
# 99                 914 Mall Loop Road     High Point    0.0  27262
#
#              Mail Address   Mail City Mail State Mail Zip      County  \
# 0            PO Box 32066       Boone        NC     28608     Watauga
# 1                       0           0          0        0        Wake
# 2                       0           0          0        0        Wake
# 3   318 Springbrook Drive    Columbus        NC     28722        Polk
# 4                       0           0          0        0        Wake
# ..                    ...         ...        ...      ...         ...
# 95    675 Merrimon Avenue   Asheville        NC     28804    Buncombe
# 96    675 Merrimon Avenue   Asheville        NC     28804    Buncombe
# 97    675 Merrimon Avenue   Asheville        NC     28804    Buncombe
# 98             PO Box 472     Madison        NC     27025  Rockingham
# 99   1177 Southgate Drive  Charleston        SC     29407    Guilford
#
#    Permit Number          Issue Date Permit Status
# 0              0 1970-01-01 00:00:00             0
# 1              0 1970-01-01 00:00:00             0
# 2              0 1970-01-01 00:00:00             0
# 3              0 1970-01-01 00:00:00             0
# 4              0 1970-01-01 00:00:00             0
# ..           ...                 ...           ...
# 95    00143575BM 2006-06-09 00:00:00        Active
# 96    00242873BM 2017-01-20 16:03:00        Active
# 97    00242873DG 2017-01-20 16:03:00        Active
# 98    00095513DI 1999-11-05 00:00:00     Cancelled
# 99    00096488BW 2002-06-07 00:00:00        Active
#
# [100 rows x 17 columns]

# %%
#cleaning the data

startdate = "01/01/2009"
enddate = "12/31/2009"
daterange = [startdate,enddate]
activelist = brewerydf.loc[(brewerydf["Business Status"] == "Active") 
                        & (brewerydf["Permit Status"] == "Active")
                        & (brewerydf["Issue Date"] < daterange[1])
                        & (brewerydf["Issue Date"] > daterange[0])
                        & (brewerydf["Permit Number"].str.contains("AE", regex=False) == True)
                          ]
activelist.tail(100)
# Out:
# Empty DataFrame
# Columns: [#, File Number, Trade Name, Corp Name, Business Status, Address, City, State, Zip, Mail Address, Mail City, Mail State, Mail Zip, County, Permit Number, Issue Date, Permit Status]
# Index: []
