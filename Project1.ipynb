# %%
# Dependencies
import pandas as pd
import requests
import json

# %%
filelist=["../Project 1/Zip_Zhvi_AllHomes.csv",
          "../Project 1/Zip_MedianListingPricePerSqft_AllHomes.csv",
          "../Project 1/Zip_MedianListingPrice_AllHomes.csv",
         "../Project 1/Zip_Zhvi_Condominum.csv",
         "../Project 1/Zip_Zhvi_SingleFamilyResidence.csv",
         "../Project 1/Zip_Zri_MultiFamilyResidenceRental.csv",
         "../Project 1/Zip_Zri_SingleFamilyResidenceRental.csv"]
dfnames=["zhviAll","Mediansqft","Median","Condo","SFR","MFRrent","SFRrent"]
dfs=[]

# %%
for i in range(len(filelist)):
    df=pd.read_csv(filelist[i], encoding="ISO-8859-1")
    dfs.append(df.loc[df["State"]=="NC"])
#    dfs[i].columns = [str(col) if str(col) != "RegionName" else str(col) + f'_{dfnames[i]}' for col in df.columns]
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(len(dfs)):   
    dfs[i].columns = [str(col) + f'_{dfnames[i]}' if col != "RegionName" else col for col in dfs[i].columns]
# Out:
#        RegionID_Condo  RegionName    City_Condo State_Condo  \
# 31              69816       28269     Charlotte          NC
# 54              69823       28277     Charlotte          NC
# 83              69672       28027       Concord          NC
# 136             69431       27587   Wake Forest          NC
# 181             69699       28078  Huntersville          NC
# ...               ...         ...           ...         ...
# 10813           69621       27943      Hatteras          NC
# 10817           69640       27968      Rodanthe          NC
# 10906           69307       27340     Saxapahaw          NC
# 10937           70164       28720     Lake Lure          NC
# 10943           69651       27982      Rodanthe          NC
#
#                       Metro_Condo    CountyName_Condo  SizeRank_Condo  \
# 31     Charlotte-Concord-Gastonia  Mecklenburg County              32
# 54     Charlotte-Concord-Gastonia  Mecklenburg County              55
# 83     Charlotte-Concord-Gastonia     Cabarrus County              84
# 136                       Raleigh         Wake County             137
# 181    Charlotte-Concord-Gastonia  Mecklenburg County             182
# ...                           ...                 ...             ...
# 10813            Kill Devil Hills         Dare County           10814
# 10817            Kill Devil Hills         Dare County           10818
# 10906                  Burlington     Alamance County           10907
# 10937                 Forest City   Rutherford County           10938
# 10943            Kill Devil Hills         Dare County           10944
#
#        1996-04_Condo  1996-05_Condo  1996-06_Condo  ...  2019-03_Condo  \
# 31          119603.0       120594.0       121479.0  ...         168949
# 54          123818.0       124950.0       126308.0  ...         221417
# 83          116820.0       117557.0       118335.0  ...         175718
# 136         139851.0       139659.0       141026.0  ...         219163
# 181              NaN            NaN            NaN  ...         312160
# ...              ...            ...            ...  ...            ...
# 10813            NaN            NaN            NaN  ...         178719
# 10817            NaN            NaN            NaN  ...         239091
# 10906            NaN            NaN            NaN  ...         413308
# 10937            NaN            NaN            NaN  ...         192691
# 10943            NaN            NaN            NaN  ...         210723
#
#        2019-04_Condo  2019-05_Condo  2019-06_Condo  2019-07_Condo  \
# 31            169417         169661         169729         169680
# 54            221760         222231         222696         222660
# 83            177379         178956         180471         180612
# 136           219451         219019         219056         219562
# 181           312465         312195         311421         309664
# ...              ...            ...            ...            ...
# 10813         178900         177385         175117         174045
# 10817         240343         236760         238608         238940
# 10906         414843         418678         426563         434071
# 10937         193321         194144         195062         195758
# 10943         211194         213539         215201         215149
#
#        2019-08_Condo  2019-09_Condo  2019-10_Condo  2019-11_Condo  \
# 31            170530         171749         173331         174888
# 54            222538         222522         223320         224611
# 83            181188         182453         184734         186276
# 136           220263         221356         222526         224476
# 181           309395         310726         313124         315112
# ...              ...            ...            ...            ...
# 10813         175940         179263         182709         184548
# 10817         241164         239520         238783         237106
# 10906         439005         438120         441410         447488
# 10937         196343         197239         199959         201761
# 10943         211917         210760         208353         206989
#
#        2019-12_Condo
# 31            176674
# 54            226348
# 83            187058
# 136           225717
# 181           316579
# ...              ...
# 10813         185511
# 10817         236632
# 10906         456458
# 10937         203288
# 10943         204126
#
# [317 rows x 292 columns]

# %%
MergedDF=dfs[0].merge(dfs[1], on='RegionName', how="outer").merge(dfs[2], on='RegionName', how="outer").merge(dfs[3], on='RegionName', how="outer").merge(dfs[4], on='RegionName', how="outer").merge(dfs[5], on='RegionName', how="outer").merge(dfs[6], on='RegionName', how="outer")
MergedDF
# Out:
#      RegionID_zhviAll  RegionName  City_zhviAll State_zhviAll  \
# 0             69816.0       28269     Charlotte            NC
# 1             69823.0       28277     Charlotte            NC
# 2             69672.0       28027       Concord            NC
# 3             69431.0       27587   Wake Forest            NC
# 4             69699.0       28078  Huntersville            NC
# ..                ...         ...           ...           ...
# 791           69651.0       27982      Rodanthe            NC
# 792           69492.0       27708        Durham            NC
# 793               NaN       27960           NaN           NaN
# 794               NaN       28619           NaN           NaN
# 795               NaN       28020           NaN           NaN
#
#                   Metro_zhviAll  CountyName_zhviAll  SizeRank_zhviAll  \
# 0    Charlotte-Concord-Gastonia  Mecklenburg County              32.0
# 1    Charlotte-Concord-Gastonia  Mecklenburg County              55.0
# 2    Charlotte-Concord-Gastonia     Cabarrus County              85.0
# 3                       Raleigh         Wake County             138.0
# 4    Charlotte-Concord-Gastonia  Mecklenburg County             183.0
# ..                          ...                 ...               ...
# 791            Kill Devil Hills         Dare County           30316.0
# 792          Durham-Chapel Hill       Durham County           30392.0
# 793                         NaN                 NaN               NaN
# 794                         NaN                 NaN               NaN
# 795                         NaN                 NaN               NaN
#
#      1996-04_zhviAll  1996-05_zhviAll  1996-06_zhviAll  ...  2018-09_SFRrent  \
# 0           130694.0         131261.0         132046.0  ...           1395.0
# 1           192153.0         192630.0         193455.0  ...           2057.0
# 2           140395.0         141002.0         141682.0  ...           1392.0
# 3           206263.0         206913.0         207259.0  ...           1635.0
# 4           176002.0         176147.0         177057.0  ...           1638.0
# ..               ...              ...              ...  ...              ...
# 791         218257.0         212818.0         214137.0  ...              NaN
# 792              NaN              NaN              NaN  ...              NaN
# 793              NaN              NaN              NaN  ...              NaN
# 794              NaN              NaN              NaN  ...              NaN
# 795              NaN              NaN              NaN  ...            876.0
#
#      2018-10_SFRrent  2018-11_SFRrent  2018-12_SFRrent  2019-01_SFRrent  \
# 0             1399.0           1412.0           1428.0           1440.0
# 1             2061.0           2073.0           2090.0           2102.0
# 2             1396.0           1406.0           1421.0           1433.0
# 3             1636.0           1637.0           1637.0           1635.0
# 4             1640.0           1647.0           1657.0           1664.0
# ..               ...              ...              ...              ...
# 791              NaN              NaN              NaN              NaN
# 792              NaN              NaN              NaN              NaN
# 793              NaN              NaN              NaN              NaN
# 794              NaN              NaN              NaN              NaN
# 795            880.0            885.0            893.0            903.0
#
#      2019-02_SFRrent  2019-03_SFRrent  2019-04_SFRrent  2019-05_SFRrent  \
# 0             1444.0           1446.0           1450.0           1455.0
# 1             2105.0           2106.0           2107.0           2121.0
# 2             1439.0           1444.0           1451.0           1469.0
# 3             1634.0           1635.0           1638.0           1650.0
# 4             1668.0           1674.0           1682.0           1702.0
# ..               ...              ...              ...              ...
# 791              NaN              NaN              NaN              NaN
# 792              NaN              NaN              NaN              NaN
# 793              NaN              NaN              NaN              NaN
# 794              NaN              NaN              NaN              NaN
# 795            909.0            908.0            906.0            873.0
#
#      2019-06_SFRrent
# 0             1465.0
# 1             2137.0
# 2             1493.0
# 3             1667.0
# 4             1721.0
# ..               ...
# 791              NaN
# 792              NaN
# 793              NaN
# 794              NaN
# 795            857.0
#
# [796 rows x 1352 columns]
