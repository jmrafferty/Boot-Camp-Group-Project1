# %%
#dependencies
import pandas as pd
import numpy as np

# %%
MergedDF = pd.read_csv("MergedDF.csv")
MergedDF

#BreweryDF=pd.read_csv('../Project 1/Boot-Camp-Group-Project1/Brewery_DistilleryData.csv')
#BreweryDF
# Out:
#      Unnamed: 0  RegionID_zhviAll  RegionName  City_zhviAll State_zhviAll  \
# 0             0           69816.0       28269     Charlotte            NC
# 1             1           69823.0       28277     Charlotte            NC
# 2             2           69672.0       28027       Concord            NC
# 3             3           69431.0       27587   Wake Forest            NC
# 4             4           69699.0       28078  Huntersville            NC
# ..          ...               ...         ...           ...           ...
# 790         790           69643.0       27972         Salvo            NC
# 791         791           69651.0       27982      Rodanthe            NC
# 792         792           69492.0       27708        Durham            NC
# 793         793               NaN       27960           NaN           NaN
# 794         794               NaN       28020           NaN           NaN
#
#                   Metro_zhviAll  CountyName_zhviAll  SizeRank_zhviAll  \
# ...

# %%
def zipstats(b,r,e,w)

    brew = b #Brewery name, as string
    year = r  #YYYY format year #need as string
    month = e #MM format month   #need as string
    zip = w  #5-digit zip  #need as integer


year1=str(int(year)+1)
year5=str(int(year)+5)
print("1 year Growth Rate")
for i in range(len(dfnames)):
    try:
        c=MergedDF.columns.get_loc(f'{year}-{month}_{dfnames[i]}')
        y=int(MergedDF.loc[MergedDF['RegionName']==zip,f'{year}-{month}_{dfnames[i]}'])
        y1=int(MergedDF.loc[MergedDF['RegionName']==zip,f'{year1}-{month}_{dfnames[i]}'])
        D1=(y1/y)-1
        print(dfnames[i],"{0:.2%}".format(D1))
    except:
        print(dfnames[i],"N/A")
print('-------------------')
print('5 Year Growth Rate')
for i in range(len(dfnames)):
    try:
        c=MergedDF.columns.get_loc(f'{year}-{month}_{dfnames[i]}')
        y=int(MergedDF.loc[MergedDF['RegionName']==zip,f'{year}-{month}_{dfnames[i]}'])
        y1=int(MergedDF.loc[MergedDF['RegionName']==zip,f'{year5}-{month}_{dfnames[i]}'])
        D1=(y1/y)-1
        print(dfnames[i],"{0:.2%}".format(D1))
    except:
        print(dfnames[i],"N/A")
